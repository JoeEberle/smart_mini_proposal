# %% [markdown]
# ![smart_mini_proposal.png](attachment:smart_mini_proposal.png)

# %% [markdown]
# ## Smart Mini Proposal
#
# ## Rapdly produce a mini proposal
#
# #### by Joe Eberle started on 04-15-2024 - https://github.com/JoeEberle/ - josepheberle@outlook.com

# %% [markdown]
# ## Mini proposal contents:

# %% [markdown]
# 1. **Objective** - Clearly state the purpose or goal of the proposal, outlining what you aim to achieve or address
# 2. **Scope** - Define the boundaries of the proposal, specifying what will be covered and what will not be addressed.
# 3. **Methodology** - Describe the approach or methods you intend to use to accomplish the objective, including any research or analysis techniques.
# 4. **Timeline** - Provide a timeline or schedule for the proposed activities, outlining key milestones and deadlines.
# 5. **Budget** - Estimate the resources required to execute the proposal, including costs associated with materials, personnel, and any other relevant expenses.

# %% [markdown]
# ## S.M.A.R.T Criteria
#
# 1. **specific** - Goals should be clear, concise, and focused on a specific outcome or result.
# 2. **measurable** - Goals should be quantifiable and include criteria for tracking progress and determining success.
# 3. **achievable** - Goals should be realistic and attainable within the constraints of resources, time, and capabilities.
# 4. **relevant** - Goals should align with overall objectives and be meaningful and relevant to the individual or organization.
# 5. **time-bound** - Goals should have a defined timeframe or deadline for completion, providing a sense of urgency and accountability.

# %%
import os
import schedule
from datetime import datetime
import pandas as pd 
import quick_logger as ql
import talking_code as tc 
import file_manager as fm 
import time


import snowflake.connector
from platform import python_version

import sqlalchemy
from snowflake.connector.pandas_tools import write_pandas, pd_writer
from sqlalchemy import create_engine
from sqlalchemy.dialects import registry
print(f"Import Libraries Complete on Date:{datetime.now().strftime('%m-%d-%Y')} at Time:{datetime.now().strftime('%I:%M:%S %p') } ")
registry.register('snowflake', 'snowflake.sqlalchemy', 'dialect')
# Out:
# C:\Users\josep\AppData\Local\Temp\ipykernel_32264\670127174.py:11: DeprecationWarning: This package has been renamed to snowflake_uuid and will be removed shortly. Please update immediately.
#   import snowflake.connector
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 11
#       7 import file_manager as fm
#       8 import time
# ---> 11 import snowflake.connector
#      12 from platform import python_version
#      14 import sqlalchemy
#
# ModuleNotFoundError: No module named 'snowflake.connector'; 'snowflake' is not a package

# %% [markdown]
# ## Optional Step 0 - Intitiate Configuration Settings and name the overall solution

# %%
import configparser 
config = configparser.ConfigParser()
cfg = config.read(r'C:\Users\JXE0313\config.ini')  

solution_name = 'smart_mini_proposal'

# %% [markdown]
# ## Optional Step 0 - Intitiate Logging and debugging

# %%
# Establish the Python Logger  
import logging # built in python library that does not need to be installed 
import quick_logger as ql

global start_stime 
start_time = ql.set_start_time()
logging = ql.create_logger_start(solution_name, start_time) 
ql.set_speaking_log(False)
ql.set_speaking_steps(False)
ql.pvlog('info',f'Process {solution_name} Step 0 - Initializing and starting Logging Process.')

# %%
def present_dataframe_as_a_list(df, term_column_number = 0, definition_column_number = 1,  output="print", title=None):
    if len(title) >= 3:
        print(f"## {title}") 
    for index, row in df.iterrows():
        if output=="print" or output=="printsay":
            print(f"{index + 1}. **{row[df.columns[term_column_number]]}** - {row[df.columns[definition_column_number]]}")
        if output=="speech" or output=="printsay":
            tc.say(f"{index + 1}. {row[df.columns[term_column_number]]} - {row[df.columns[definition_column_number]]}")            
    return

# %%
import json
import pandas as pd

smart_criteria = [     # Define the main treatment modalities with brief descriptions
    {"criteria_name": "specific", "description": "Goals should be clear, concise, and focused on a specific outcome or result."},
    {"criteria_name": "measurable", "description": "Goals should be quantifiable and include criteria for tracking progress and determining success." },
    {"criteria_name": "achievable", "description": "Goals should be realistic and attainable within the constraints of resources, time, and capabilities." },
    {"criteria_name": "relevant", "description": "Goals should align with overall objectives and be meaningful and relevant to the individual or organization."},
    {"criteria_name": "time-bound", "description": "Goals should have a defined timeframe or deadline for completion, providing a sense of urgency and accountability."}
]

# Save the JSON variable to a file
with open("smart_criteria.json", "w") as file:
    json.dump(smart_criteria, file)

# # Load the JSON file into a pandas DataFrame
with open("smart_criteria.json", "r") as file:
    df = pd.DataFrame(json.load(file))
df.to_excel("smart_criteria.xlsx") 
present_dataframe_as_a_list(df, 0, 1, "print","S.M.A.R.T Criteria")
# Out:
# ## S.M.A.R.T Criteria
# 1. **specific** - Goals should be clear, concise, and focused on a specific outcome or result.
# 2. **measurable** - Goals should be quantifiable and include criteria for tracking progress and determining success.
# 3. **achievable** - Goals should be realistic and attainable within the constraints of resources, time, and capabilities.
# 4. **relevant** - Goals should align with overall objectives and be meaningful and relevant to the individual or organization.
# 5. **time-bound** - Goals should have a defined timeframe or deadline for completion, providing a sense of urgency and accountability.

# %%
mini_proposal_contents = [     # Define the main treatment modalities with brief descriptions
    {"section": "Objective", "description": "Clearly state the purpose or goal of the proposal, outlining what you aim to achieve or address"},
    {"section": "Scope", "description": "Define the boundaries of the proposal, specifying what will be covered and what will not be addressed." },
    {"section": "Methodology", "description": "Describe the approach or methods you intend to use to accomplish the objective, including any research or analysis techniques." },
    {"section": "Timeline", "description": "Provide a timeline or schedule for the proposed activities, outlining key milestones and deadlines."},
    {"section": "Budget", "description": "Estimate the resources required to execute the proposal, including costs associated with materials, personnel, and any other relevant expenses."}
]

# %% [markdown]
# Certainly, here are brief descriptions of each of these common breast cancer drugs:
#
# 1. **Docetaxel**: Docetaxel is a chemotherapy medication that works by interfering with the growth and spread of cancer cells. It is commonly used to treat various types of cancer, including breast cancer, by inhibiting cell division and growth.
#
# 2. **Paclitaxel**: Paclitaxel is another chemotherapy drug that works by preventing cancer cells from dividing and growing. It is used to treat breast cancer by disrupting the microtubule structures within cancer cells, leading to cell death.
#
# 3. **Doxorubicin**: Doxorubicin is a chemotherapy drug that belongs to the anthracycline class. It works by damaging the DNA of cancer cells, preventing their replication and leading to cell death. Doxorubicin is commonly used in combination with other drugs for breast cancer treatment.
#
# 4. **Epirubicin**: Epirubicin is also an anthracycline chemotherapy drug similar to doxorubicin. It works by damaging the DNA of cancer cells and is used in combination with other drugs for breast cancer treatment, particularly in patients who have not responded to other therapies.
#
# 5. **Capecitabine**: Capecitabine is an oral chemotherapy drug that is converted into 5-fluorouracil (5-FU) in the body. It interferes with the growth of cancer cells by inhibiting DNA synthesis and is commonly used to treat advanced or metastatic breast cancer.
#
# 6. **Carboplatin**: Carboplatin is a chemotherapy drug that works by interfering with DNA replication in cancer cells, leading to cell death. It is used in combination with other drugs for the treatment of certain types of breast cancer, particularly in patients with BRCA mutations.
#
# 7. **Cyclophosphamide**: Cyclophosphamide is a chemotherapy drug that works by suppressing the immune system and interfering with DNA replication in cancer cells. It is used in combination with other drugs for the treatment of breast cancer, particularly in the neoadjuvant or adjuvant setting.
#
# 8. **Fluorouracil (5-FU)**: Fluorouracil, also known as 5-FU, is a chemotherapy drug that interferes with the synthesis of DNA and RNA in cancer cells, leading to cell death. It is commonly used in combination with other drugs for the treatment of breast cancer, particularly in the adjuvant setting.
#
# 9. **Methotrexate**: Methotrexate is a chemotherapy drug that inhibits the synthesis of DNA and RNA in cancer cells, leading to cell death. It is used in combination with other drugs for the treatment of breast cancer, particularly in the adjuvant setting.
#
# 10. **Protein-bound paclitaxel**: Protein-bound paclitaxel, also known as nab-paclitaxel, is a chemotherapy drug that is paclitaxel bound to albumin nanoparticles. It is used to treat metastatic breast cancer by disrupting microtubule function in cancer cells, leading to cell death. It is often used as an alternative to standard paclitaxel chemotherapy.

# %%
Sure, here's the code to persist the JSON to disk and convert it into a DataFrame:

```python
import json
import pandas as pd

# JSON data
chemotherapy_side_effects = {
    "chemotherapy_side_effects": {
        "Docetaxel": {
            "side_effects": [
                "Nausea and vomiting",
                "Fatigue",
                "Hair loss",
                "Mouth sores",
                "Diarrhea",
                "Decreased white blood cell count (neutropenia)",
                "Peripheral neuropathy",
                "Fluid retention",
                "Nail changes"
            ]
        },
        "Paclitaxel": {
            "side_effects": [
                "Hair loss",
                "Nausea and vomiting",
                "Diarrhea",
                "Muscle or joint pain",
                "Peripheral neuropathy",
                "Decreased white blood cell count",
                "Allergic reactions",
                "Changes in taste",
                "Nail changes"
            ]
        },
        "Doxorubicin": {
            "side_effects": [
                "Nausea and vomiting",
                "Hair loss",
                "Mouth sores",
                "Diarrhea",
                "Fatigue",
                "Decreased white blood cell count",
                "Increased risk of infections",
                "Cardiotoxicity",
                "Red urine discoloration"
            ]
        },
        "Epirubicin": {
            "side_effects": [
                "Nausea and vomiting",
                "Hair loss",
                "Mouth sores",
                "Diarrhea",
                "Fatigue",
                "Decreased white blood cell count",
                "Cardiotoxicity",
                "Red urine discoloration"
            ]
        },
        "Capecitabine": {
            "side_effects": [
                "Nausea and vomiting",
                "Diarrhea",
                "Hand-foot syndrome",
                "Fatigue",
                "Decreased white blood cell count",
                "Mouth sores",
                "Changes in taste",
                "Loss of appetite"
            ]
        },
        "Carboplatin": {
            "side_effects": [
                "Nausea and vomiting",
                "Fatigue",
                "Anemia",
                "Decreased white blood cell count",
                "Increased risk of infections",
                "Kidney toxicity",
                "Allergic reactions"
            ]
        },
        "Cyclophosphamide": {
            "side_effects": [
                "Nausea and vomiting",
                "Hair loss",
                "Mouth sores",
                "Diarrhea",
                "Fatigue",
                "Decreased white blood cell count",
                "Increased risk of infections",
                "Bladder irritation",
                "Amenorrhea"
            ]
        },
        "Fluorouracil (5-FU)": {
            "side_effects": [
                "Nausea and vomiting",
                "Diarrhea",
                "Mouth sores",
                "Fatigue",
                "Decreased white blood cell count",
                "Increased risk of infections",
                "Hand-foot syndrome",
                "Cardiotoxicity"
            ]
        },
        "Methotrexate": {
            "side_effects": [
                "Nausea and vomiting",
                "Diarrhea",
                "Mouth sores",
                "Fatigue",
                "Decreased white blood cell count",
                "Increased risk of infections",
                "Liver toxicity",
                "Kidney toxicity",
                "Skin rash"
            ]
        },
        "Protein-bound paclitaxel": {
            "side_effects": [
                "Hair loss",
                "Nausea and vomiting",
                "Diarrhea",
                "Muscle or joint pain",
                "Peripheral neuropathy",
                "Decreased white blood cell count",
                "Allergic reactions",
                "Fatigue",
                "Changes in taste"
            ]
        }
    }
}

# Write JSON to file
with open('chemotherapy_side_effects.json', 'w') as f:
    json.dump(chemotherapy_side_effects, f)

# Load JSON into DataFrame
with open('chemotherapy_side_effects.json', 'r') as f:
    data = json.load(f)
    df_chemotherapy_side_effects = pd.json_normalize(data['chemotherapy_side_effects'])

# Display DataFrame
print(df_chemotherapy_side_effects)
```

This code will create a JSON file named `chemotherapy_side_effects.json` containing the chemotherapy side effects data, and then load it into a DataFrame named `df_chemotherapy_side_effects`.

# %%
with open("mini_proposal_sections.json", "w") as file:   # Save the JSON variable to a file
    json.dump(mini_proposal_contents, file)

with open("mini_proposal_sections.json", "r") as file:      # # Load the JSON file into a pandas DataFrame
    df_mini_proposal_contents = pd.DataFrame(json.load(file))
df_mini_proposal_contents.to_excel("mini_proposal_sections.xlsx") 
present_dataframe_as_a_list(df_mini_proposal_contents, 0, 1, "print")

# %% [markdown]
# **Mini Proposal: Evaluation of Chemotherapy Side Effects in Breast Cancer Patients**
#
# **Objective:**
# The objective of this study is to assess and compare the side effects of chemotherapy drugs commonly used in the treatment of breast cancer within the region. Specifically, we aim to evaluate the incidence and severity of side effects associated with each chemotherapy drug and provide a comparative analysis to identify potential differences in side effect risk. Finally, we will prepare a prototype "recommender" tool that matches the patient to medicine via their demographic risk profile and risk of the medication. NOTE - THIS PROJECT WILL NOT EVALUATE PATIENT OUTCOMES - Only side affects.
#
# **Scope:**
# This study will focus on breast cancer patients who underwent chemotherapy treatment within the region during the year 2023. We will analyze actual patient data to assess the occurrence of common side effects associated with chemotherapy drugs such as docetaxel, paclitaxel, doxorubicin, epirubicin, and others.
#
# **Methodology:**
# 1. **Data Collection:** Obtain anonymized patient data from regional healthcare databases for breast cancer patients treated with chemotherapy in 2023.
# 2. **Side Effect Identification:** Identify and categorize common side effects reported by patients during chemotherapy treatment.
# 3. **ICD-10 Code Assignment:** Assign ICD-10 codes to represent each identified side effect, ensuring standardized classification.
# 4. **Data Analysis:** Analyze the frequency and severity of each side effect for different chemotherapy drugs used in breast cancer treatment.
# 5. **Comparative Analysis:** Conduct a comparative analysis to assess the relative risk of side effects associated with each chemotherapy drug.
#
# **Timeline:**
# - Data Collection: Month 1-2
# - Side Effect Identification: Month 2-3
# - ICD-10 Code Assignment: Month 3-4
# - Data Analysis: Month 4-5
# - Comparative Analysis: Month 5-6
#
# **Budget:**
# - Personnel: 4-6 data scientists (4 hours per week)
# - Data Access and Processing: Use existing open source tools and HealtheIntent
# - Software and Tools: Python, Snowflake, HealtheIntent,
#
# **Deliverables:**
# - Comprehensive report detailing the incidence and severity of chemotherapy side effects in breast cancer patients.
# - Comparative analysis highlighting differences in side effect risk among chemotherapy drugs.
# - Presentation of findings to relevant stakeholders for further discussion and action.
#
# This study will provide valuable insights into the safety profile of chemotherapy drugs used in breast cancer treatment, aiding clinicians in making informed treatment decisions and optimizing patient care.

# %% [markdown]
# **Mini Proposal: Evaluation of Anxiety and Depression in Patients with a Major Medical Diagnosis**
#
# **Objective:**
# The objective of this study is to assess the prevalence of anxiety and depression in patients diagnosed with a major medical condition (such as cancer, heart attack, stroke, etc.) and evaluate the impact of new cases of anxiety and depression on patient compliance with prescribed treatment protocols. Additionally, we aim to determine whether the assignment of behavioral health specialists or care managers could improve coping mechanisms and treatment adherence.
#
# **Scope:**
# This study will focus on patients newly diagnosed with a major medical condition within the past calandar year, excluding those with a history of prior anxiety or chronic depression. We will assess the prevalence of anxiety and depression symptoms using validated screening tools and evaluate their impact on treatment compliance. The study will explore the potential benefits of integrating behavioral health specialists or care managers into the patient care pathway to provide support and enhance coping mechanisms.
#
# **Methodology:**
# 1. **Condition Identification:** Identify conditions with a major medical burden and high mortality.
# 2. **Patient Selection:** Identify patients newly diagnosed with a major medical condition within the past year from electronic medical records.
# 3. **Anxiety and Depression Screening:** Evaluate claims or validated screening tools (e.g., PHQ-9, GAD-7) to assess anxiety and depression symptoms in eligible patients.
# 4. **Treatment Protocol Compliance Assessment:** Evaluate patient compliance with prescribed treatment protocols through HealeIntent medication / procedure record review.
# 5. **New Case Analysis:** Analyze the impact of newly diagnosed cases of anxiety and depression on treatment compliance and outcomes.
# 6. **Intervention Evaluation:** Assess the effectiveness of assigning behavioral health specialists or care managers to patients with newly diagnosed anxiety and depression in improving coping mechanisms and treatment adherence.
#
# **Timeline:**
# - Patient Selection and Screening: Month 1-2
# - Treatment Protocol Compliance Assessment: Month 3-4
# - New Case Analysis: Month 4-5
# - Intervention Evaluation: Out of scope- Business decision
#
# **Budget:**
# - Personnel: 3-4 data scientists (4 hours per week)
# - Data Access and Processing: Use existing open source tools and HealtheIntent
# - Software and Tools: Python, Snowflake, HealtheIntent,
#
# **Deliverables:**
# - Comprehensive report detailing the prevalence of anxiety and depression in patients with a major medical diagnosis and their impact on treatment compliance.
# - Analysis of the effectiveness of assigning behavioral health specialists or care managers in improving coping mechanisms and treatment adherence.
# - Recommendations for integrating behavioral health support into the patient care pathway to enhance overall patient outcomes.
#
# This study will provide valuable insights into the psychological impact of major medical diagnoses and the importance of addressing anxiety and depression in patient care. It will inform healthcare providers about the potential benefits of integrating behavioral health support services to improve patient well-being and treatment outcomes.

# %% [markdown]
# **Mini Proposal: Evaluation of Patient Enrollment in a New Health Program using the Transtheoretical Model**
#
# **Objective:**
# The objective of this study is to assess patients' willingness to enroll in a new health program using the Transtheoretical Model (TTM). Specifically, we aim to evaluate the impact of various risk factors, such as poor emotional regulatory control and sleep habits, on patients' readiness to enroll in the program. Additionally, we will use available claims and medical encounter data to assess patients' likelihood of responding positively to care management outreach efforts.
#
# **Scope:**
# This study will focus on patients eligible for enrollment in a new health program within the healthcare system. We will assess patients' readiness to enroll in the program based on the stages of change outlined in the Transtheoretical Model. Risk factors, including poor emotional regulatory control and circadian rhythm disruptions, will be evaluated using simulated risk assessments based on CMS BRFSS survey data and available claims or medical encounter data.
#
# **Methodology:**
# 1. **Patient Eligibility Determination:** Identify eligible patients for enrollment in the new health program based on predefined criteria.
# 2. **Transtheoretical Model Assessment:** Assess patients' readiness to enroll in the program using the stages of change outlined in the Transtheoretical Model (precontemplation, contemplation, preparation, action, maintenance).
# 3. **Risk Assessment:** Simulate risk assessments for identified risk factors, such as poor emotional regulatory control and circadian rhythm disruptions, using CMS BRFSS survey data. Utilize available claims or medical encounter data to further assess patients' risk profiles.
# 4. **Likelihood of Positive Response Assessment:** Determine patients' likelihood of responding positively to care management outreach efforts based on their readiness to change and risk profiles.
# 5. **Data Analysis:** Analyze the relationship between patients' readiness to enroll in the health program, risk factors, and likelihood of positive response to care management outreach.
#
# **Timeline:**
# - Patient Eligibility Determination: Month 1-2
# - Transtheoretical Model Assessment: Month 2-3
# - Risk Assessment: Month 3-4
# - Likelihood of Positive Response Assessment: Month 4-5
# - Data Analysis: Month 5-6 - with help form care managers
#
# **Timeline:**
# - Patient Selection and Screening: Month 1-2
# - Treatment Protocol Compliance Assessment: Month 3-4
# - New Case Analysis: Month 4-5
# - Intervention Evaluation: Out of scope- Business decision
#
# **Budget:**
# - Personnel: 3-4 data scientists (4 hours per week)
# - Data Access and Processing: Use existing open source tools and HealtheIntent
# - Software and Tools: Python, Snowflake, HealtheIntent,
#
# **Deliverables:**
# - Report outlining patients' readiness to enroll in the new health program based on the Transtheoretical Model.
# - Analysis of risk factors, including poor emotional regulatory control and circadian rhythm disruptions, affecting patients' readiness to enroll.
# - Assessment of patients' likelihood of responding positively to care management outreach efforts based on readiness to change and risk profiles.
# - Recommendations for tailored outreach strategies to improve patient enrollment and engagement in the new health program.
#
# This study will provide valuable insights into the factors influencing patients' willingness to enroll in a new health program and inform the development of targeted interventions to improve patient engagement and outcomes.

# %% [markdown]
# **Mini Proposal: Evaluation of Diabetes Outcomes in HealtheIntent Patients**
#
# **Objective:**
# The objective of this study is to evaluate diabetes outcomes among HealtheIntent patients diagnosed with Diabetes Mellitus in 2023. Specifically, we aim to assess outcomes such as A1C control, mortality rates, amputations, hospitalizations, emergency department (ED) visits, and the onset of comorbid conditions (e.g., heart disease, chronic kidney disease, stroke). Additionally, we will analyze patients' geographic locations to identify regions with excellent or poor diabetes outcomes compared to the rest of the region.
#
# **Scope:**
# This study will include all HealtheIntent patients diagnosed with Diabetes Mellitus in 2023. We will evaluate various diabetes outcomes and comorbid conditions to determine which practices or treatment protocols result in the best outcomes for diabetic patients. Geographic location data will be used to assess regional disparities in diabetes outcomes.
#
# **Methodology:**
# 1. **Patient Selection:** Identify all HealtheIntent patients diagnosed with Diabetes Mellitus in 2023 from electronic health records.
# 2. **Outcome Evaluation:** Assess diabetes outcomes, including A1C control (poor and good), mortality rates, amputations, hospitalizations, and ED visits.
# 3. **Comorbid Condition Onset:** Evaluate the onset of comorbid conditions such as heart disease, chronic kidney disease, and stroke among diabetic patients.
# 4. **Practices and Treatment Protocol Analysis:** Analyze the practices and treatment protocols associated with the best outcomes for diabetic patients.
# 5. **Geographic Analysis:** Assess patients' geographic locations to identify regions with excellent or poor diabetes outcomes compared to the rest of the region.
#
# **Timeline:**
# - Patient Selection and Data Collection: Month 1-2
# - Outcome Evaluation: Month 3-4
# - Comorbid Condition Onset Analysis: Month 5-6
# - Practices and Treatment Protocol Analysis: Month 7-8
# - Geographic Analysis: Month 9-10
#
# **Budget:**
# - Personnel: 3-4 data scientists (4 hours per week)
# - Data Access and Processing: Use existing open source tools and HealtheIntent
# - Software and Tools: Python, Snowflake, HealtheIntent,
#
# **Deliverables:**
# - Comprehensive report detailing diabetes outcomes among HealtheIntent patients, including A1C control, mortality rates, amputations, hospitalizations, ED visits, and comorbid condition onset.
# - Analysis of practices and treatment protocols associated with the best outcomes for diabetic patients.
# - Geographic analysis identifying regions with excellent or poor diabetes outcomes compared to the rest of the region.
# - Recommendations for improving diabetes care practices and treatment protocols based on study findings.
#
# This study will provide valuable insights into diabetes management practices and treatment protocols, as well as geographic disparities in diabetes outcomes. It will inform healthcare providers about effective strategies for improving diabetes care and reducing the burden of diabetes-related complications.

# %% [markdown]
# ## Step 0 - Process End - display log

# %%
# Calculate and classify the process performance 
status = ql.calculate_process_performance(solution_name, start_time) 
print(ql.append_log_file(solution_name))

# %% [markdown]
# #### https://github.com/JoeEberle/ -- josepheberle@outlook.com
